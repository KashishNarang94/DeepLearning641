# %%
import seaborn as sns
import matplotlib.pyplot as plt
# It is Used to plot the decision Boundary within scattered data points
def plot_data(w, b, data, title): 
    plot_x = np.array([-2, 3])
    # getting corresponding y co-ordinates of the decision boundary
    plot_y = (-1/w[1]) * (w[0] * plot_x + b)
    sns.FacetGrid(data, hue="label", size = 4).map(plt.scatter, 0, 1).add_legend()
    plt.plot(plot_x, plot_y)
    plt.xlabel("x - axis")
    plt.ylabel("y - axis")
    plt.title(title)
    plt.show()

# %%
import numpy as np
# Implementation of PTA Algorithm
def PTA(data_list, data_label, data, title):
    w = [0, 0]
    b = 0
    w = np.array(w)
    count = 1
    while(True): # Iterating till there is no Error
        flag = 0
        print("Step ",count,"-> Weights :",w,", Bias :", b)
        plot_data(w, b, data, title)
        for i in range(0, len(data_list)):
            mat1 = np.array(data_list[i])
            t = np.dot(w.T, mat1)
            t += b
            t = t * data_label[i]
            if(t <= 0): # Error Condition
                w = np.add(w, (np.array(data_list[i])*(data_label[i]))) #Updating the weights by w = w + yx
                b += (1*data_label[i])
                flag = 1
                break
        if(count==30):
            break
        count += 1
        if(flag == 0):
            break
    print("\nFinal Weights : ", w)
    print("Final Bias :", b)
    return w,b

# %% [markdown]
# ### PTA for OR operation

# %%
import pandas as pd
or_list = [[0,0], [0,1], [1,0], [1,1]]
or_label = [-1, 1, 1, 1]

# %%
or_data = pd.DataFrame(or_list)
or_data["label"] = or_label
or_data
# Out:
#    0  1  label
# 0  0  0     -1
# 1  0  1      1
# 2  1  0      1
# 3  1  1      1

# %%
# Calling PTA Algortihm for OR operation
w, b = PTA(or_list, or_label, or_data, "Decision Boundary for OR operation")
# Out:
# Step  1 -> Weights : [0 0] , Bias : 0
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   import sys
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in multiply
#   import sys
# Step  2 -> Weights : [0 0] , Bias : -1
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   import sys
# Step  3 -> Weights : [0 1] , Bias : 0
# Step  4 -> Weights : [0 1] , Bias : -1
# Step  5 -> Weights : [0 2] , Bias : 0
# Step  6 -> Weights : [0 2] , Bias : -1
# Step  7 -> Weights : [1 2] , Bias : 0
# Step  8 -> Weights : [1 2] , Bias : -1
# Step  9 -> Weights : [2 2] , Bias : 0
# Step  10 -> Weights : [2 2] , Bias : -1
# Final Weights :  [2 2]
# Final Bias : -1

# %%
# Plotting the final Decision Boundary after convergence
plot_data(w, b, or_data, "Decision Boundary for OR operation")

# %% [markdown]
# ### PTA for XOR operation

# %%
xor_list = [[0,0], [0,1], [1,0], [1,1]]
xor_label = [-1,1,1,-1]
xor_data = pd.DataFrame(xor_list)
xor_data["label"] = xor_label
xor_data
# Out:
#    0  1  label
# 0  0  0     -1
# 1  0  1      1
# 2  1  0      1
# 3  1  1     -1

# %%
w, b = PTA(xor_list, xor_label, xor_data, "Decision Boundary for XOR operation")
# Out:
# Step  1 -> Weights : [0 0] , Bias : 0
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   import sys
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in multiply
#   import sys
# Step  2 -> Weights : [0 0] , Bias : -1
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   import sys
# Step  3 -> Weights : [0 1] , Bias : 0
# Step  4 -> Weights : [0 1] , Bias : -1
# Step  5 -> Weights : [0 2] , Bias : 0
# Step  6 -> Weights : [0 2] , Bias : -1
# Step  7 -> Weights : [1 2] , Bias : 0
# Step  8 -> Weights : [1 2] , Bias : -1
# Step  9 -> Weights : [2 2] , Bias : 0
# Step  10 -> Weights : [2 2] , Bias : -1
# Step  11 -> Weights : [1 1] , Bias : -2
# Step  12 -> Weights : [1 2] , Bias : -1
# Step  13 -> Weights : [2 2] , Bias : 0
# Step  14 -> Weights : [2 2] , Bias : -1
# Step  15 -> Weights : [1 1] , Bias : -2
# Step  16 -> Weights : [1 2] , Bias : -1
# Step  17 -> Weights : [2 2] , Bias : 0
# Step  18 -> Weights : [2 2] , Bias : -1
# Step  19 -> Weights : [1 1] , Bias : -2
# Step  20 -> Weights : [1 2] , Bias : -1
# Step  21 -> Weights : [2 2] , Bias : 0
# Step  22 -> Weights : [2 2] , Bias : -1
# Step  23 -> Weights : [1 1] , Bias : -2
# Step  24 -> Weights : [1 2] , Bias : -1
# Step  25 -> Weights : [2 2] , Bias : 0
# Step  26 -> Weights : [2 2] , Bias : -1
# Step  27 -> Weights : [1 1] , Bias : -2
# Step  28 -> Weights : [1 2] , Bias : -1
# Step  29 -> Weights : [2 2] , Bias : 0
# Step  30 -> Weights : [2 2] , Bias : -1
# Final Weights :  [1 1]
# Final Bias : -2

# %%
# plot_data(w, b, xor_data, "Decision Boundary for XOR operation")

# %% [markdown]
# #### XOR is not Converging Using PTA
# 1. By running algorithm for 15 steps we can see that 8-11, 12-15,... the weights in these steps are repeating (So we can say that these 4 weights are repeating itself).
# 2. Step 8 to 11 are being repeated over the iterations, hence they are not converging.

# %% [markdown]
# ### PTA for AND operation

# %%
and_list = [[0,0], [0,1], [1,0], [1,1]]
and_label = [-1,-1,-1,1]
and_data = pd.DataFrame(and_list)
and_data["label"] = and_label
and_data
# Out:
#    0  1  label
# 0  0  0     -1
# 1  0  1     -1
# 2  1  0     -1
# 3  1  1      1

# %%
# Calling PTA Algorithm on AND Data
w, b = PTA(and_list, and_label, and_data, "Decision Boundary for AND operation")
# Out:
# Step  1 -> Weights : [0 0] , Bias : 0
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   import sys
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in multiply
#   import sys
# Step  2 -> Weights : [0 0] , Bias : -1
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   import sys
# Step  3 -> Weights : [1 1] , Bias : 0
# Step  4 -> Weights : [1 1] , Bias : -1
# Step  5 -> Weights : [1 0] , Bias : -2
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   import sys
# Step  6 -> Weights : [2 1] , Bias : -1
# Step  7 -> Weights : [2 0] , Bias : -2
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   import sys
# Step  8 -> Weights : [1 0] , Bias : -3
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   import sys
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in multiply
#   import sys
# Step  9 -> Weights : [2 1] , Bias : -2
# Step  10 -> Weights : [1 1] , Bias : -3
# Step  11 -> Weights : [2 2] , Bias : -2
# Step  12 -> Weights : [2 1] , Bias : -3
# Step  13 -> Weights : [3 2] , Bias : -2
# Step  14 -> Weights : [3 1] , Bias : -3
# Step  15 -> Weights : [2 1] , Bias : -4
# Step  16 -> Weights : [3 2] , Bias : -3
# Step  17 -> Weights : [2 2] , Bias : -4
# Step  18 -> Weights : [3 3] , Bias : -3
# Step  19 -> Weights : [3 2] , Bias : -4
# Final Weights :  [3 2]
# Final Bias : -4

# %%
# Plotting the final Decision Boundary after convergence
plot_data(w, b, and_data, "Decision Boundary for AND operation")

# %% [markdown]
# ### PTA for NOT Operation

# %%
not_list = [[0], [1]]
not_label = [1,-1]
not_data = pd.DataFrame(not_list)
not_data["label"] = not_label
not_data
# Out:
#    0  label
# 0  0      1
# 1  1     -1

# %%
# Plotting 1D data with decision Boundary
def plot_not_data(w, b, not_data, title):
    xmin, xmax = plt.xlim()
    a = -b / w[0]
    xx = np.linspace(xmin, xmax)
    yy = a * xx - (b) / w[0]
    plt.scatter([0,0], not_data[0])
    plt.plot(xx, yy, 'k-')
    plt.xlabel("x - axis")
    plt.ylabel("y - axis")
    plt.title(title)
    plt.show()

# %%
# PTA Algorithm
w = [0]
b = 0
w = np.array(w)
count = 1
while(True): # Iterating till there is no Error
    flag = 0
    print("Step ",count,"-> Weights :",w,", Bias :", b)
    plot_not_data(w, b, not_data, "Decision Boundary for NOT operation")
    for i in range(0, len(not_list)):
        mat1 = np.array(not_list[i])
        t = np.dot(w.T, mat1)
        t += b
        t = t * not_label[i]
        if(t <= 0): # Error Condition
            w = np.add(w, (np.array(not_list[i])*(not_label[i]))) # Updating the weights by w = w + yx
            b += (1*not_label[i])
            flag = 1
            break
    count += 1
    if(flag == 0):
        break
# Out:
# Step  1 -> Weights : [0] , Bias : 0
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in long_scalars
#   after removing the cwd from sys.path.
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in long_scalars
# Step  2 -> Weights : [0] , Bias : 1
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in long_scalars
#   after removing the cwd from sys.path.
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in multiply
#
# C:\Users\Chirag\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in long_scalars
# Step  3 -> Weights : [-1] , Bias : 0
# Step  4 -> Weights : [-1] , Bias : 1
# Step  5 -> Weights : [-2] , Bias : 0
# Step  6 -> Weights : [-2] , Bias : 1

# %%
# Plotting the final Decision Boundary after convergence
plot_not_data(w, b, not_data, "Decision Boundary for NOT operation")
